F4 theta m  AF4 alpha std  AF4 alpha m  AF4 beta std  AF4 beta m
# 0        2.917284       1.095649     1.342387      1.141837    1.820216
# 1        2.876174       1.178849     1.939520      0.903631    2.145510
# 2        2.286765       1.591144     1.949241      1.006042    2.228659
# 3        2.486281       0.684482     2.173874      0.937085    2.165614
# 4        3.115490       1.235855     2.453826      0.840093    2.126146
# ...           ...            ...          ...           ...         ...
# 2875     1.842909       0.271320     1.235039      1.081958    2.239726
# 2876     2.014998       0.249743     1.573777      1.254084    2.494333
# 2877     2.111638       0.943919     1.525629      1.244487    2.555489
# 2878     2.004392       1.395303     1.550127      1.095299    2.372722
# 2879     1.958594       1.251051     1.478645      1.559969    2.252187
#
# [2880 rows x 113 columns]

# %%
ESR.columns
# Out:
# Index(['Class', 'AF3 delta std', 'AF3 delta m', 'AF3 theta std', 'AF3 theta m',
#        'AF3 alpha std', 'AF3 alpha m', 'AF3 beta std', 'AF3 beta m',
#        'F7 delta std',
#        ...
#        'F8 beta std', 'F8 beta m', 'AF4 delta std', 'AF4 delta m',
#        'AF4 theta std', 'AF4 theta m', 'AF4 alpha std', 'AF4 alpha m',
#        'AF4 beta std', 'AF4 beta m'],
#       dtype='object', length=113)

# %%
ESR.isnull().sum()  #isnull().sum()  gives the sum of missing value in the data set or  nan values here in the data set
# Out:
# Class            0
# AF3 delta std    0
# AF3 delta m      0
# AF3 theta std    0
# AF3 theta m      0
#                 ..
# AF4 theta m      0
# AF4 alpha std    0
# AF4 alpha m      0
# AF4 beta std     0
# AF4 beta m       0
# Length: 113, dtype: int64

# %%
ESR.info() # gives the information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Columns: 113 entries, Class to AF4 beta m
# dtypes: float64(113)
# memory usage: 2.5 MB

# %%
ESR.tail(2881) #gives the entire description of the data set
# Out:
#       Class  AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  \
# 0       1.0    3566.375438  2062.665095       1.040973     2.574824
# 1       1.0    3565.986713  2061.826341       1.347088     2.154989
# 2       1.0    3566.977885  2062.639807       1.083747     2.186981
# 3       1.0    3566.342634  2063.069909       1.208843     2.160716
# 4       1.0    3567.798629  2062.549327       1.378424     3.255706
# ...     ...            ...          ...            ...          ...
# 2875    0.0    3572.183440  2063.784708       1.229472     2.118878
# 2876    0.0    3571.739312  2062.870495       1.131872     2.143829
# 2877    0.0    3571.184751  2063.216128       1.139433     2.066175
# 2878    0.0    3570.595817  2062.900476       1.013536     1.579048
# 2879    0.0    3570.330797  2062.512769       1.654649     1.834446
#
#       AF3 alpha std  AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  ...  \
# 0          1.376404     1.657806      0.933377    2.429998   3564.653552  ...
# 1          0.904145     2.603965      1.175508    2.292886   3564.071577  ...
# 2          1.155864     2.293261      1.144330    2.107225   3564.207493  ...
# 3          1.143995     2.283394      1.008707    2.047132   3564.536023  ...
# 4          0.795261     1.726990      0.914162    1.746653   3565.157175  ...
# ...             ...          ...           ...         ...           ...  ...
# 2875       0.554802     1.531674      1.515939    2.064786   3564.057879  ...
# 2876       0.600867     2.161191      1.481767    1.981241   3564.245318  ...
# 2877       0.613243     2.005979      1.202326    1.918536   3564.496395  ...
# 2878       0.214779     1.701602      1.314499    1.782709   3564.497194  ...
# 2879       0.618655     1.475103      1.296110    1.675299   3563.138833  ...
#
#       F8 beta std  F8 beta m  AF4 delta std  AF4 delta m  AF4 theta std  \
# 0        0.991871   1.800747    3564.807696  2061.398768       1.839022
# 1        0.852802   1.620589    3565.004893  2061.989687       1.314281
# 2        1.075723   1.422287    3567.117563  2061.465328       1.628649
# 3        0.696173   1.416980    3565.482402  2060.885464       1.049679
# 4        0.743514   1.384104    3566.585859  2061.257282       1.500156
# ...           ...        ...            ...          ...            ...
# 2875     1.347489   1.589724    3568.988084  2063.376781       0.731822
# 2876     1.269081   1.474497    3569.102041  2063.103722       0.914127
# 2877     1.233228   1.539265    3569.136435  2063.114849       0.982602
# 2878     1.138962   1.475072    3567.959877  2062.375466       1.036738
# 2879     1.377477   1.619593    3568.175775  2062.192979       0.981879
#
#       AF4 theta m  AF4 alpha std  AF4 alpha m  AF4 beta std  AF4 beta m
# 0        2.917284       1.095649     1.342387      1.141837    1.820216
# 1        2.876174       1.178849     1.939520      0.903631    2.145510
# 2        2.286765       1.591144     1.949241      1.006042    2.228659
# 3        2.486281       0.684482     2.173874      0.937085    2.165614
# 4        3.115490       1.235855     2.453826      0.840093    2.126146
# ...           ...            ...          ...           ...         ...
# 2875     1.842909       0.271320     1.235039      1.081958    2.239726
# 2876     2.014998       0.249743     1.573777      1.254084    2.494333
# 2877     2.111638       0.943919     1.525629      1.244487    2.555489
# 2878     2.004392       1.395303     1.550127      1.095299    2.372722
# 2879     1.958594       1.251051     1.478645      1.559969    2.252187
#
# [2880 rows x 113 columns]

# %%
ESR.loc[3] # it fetches the particular row  loc[row number]
# Out:
# Class               1.000000
# AF3 delta std    3566.342634
# AF3 delta m      2063.069909
# AF3 theta std       1.208843
# AF3 theta m         2.160716
#                     ...
# AF4 theta m         2.486281
# AF4 alpha std       0.684482
# AF4 alpha m         2.173874
# AF4 beta std        0.937085
# AF4 beta m          2.165614
# Name: 3, Length: 113, dtype: float64

# %%
ESR.loc[3,"AF3 delta std"]
# Out:
# 3566.3426340136084

# %%
ESR.loc[0:4] # to extract the particular portion of the data set
# Out:
#    Class  AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  \
# 0    1.0    3566.375438  2062.665095       1.040973     2.574824
# 1    1.0    3565.986713  2061.826341       1.347088     2.154989
# 2    1.0    3566.977885  2062.639807       1.083747     2.186981
# 3    1.0    3566.342634  2063.069909       1.208843     2.160716
# 4    1.0    3567.798629  2062.549327       1.378424     3.255706
#
#    AF3 alpha std  AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  ...  \
# 0       1.376404     1.657806      0.933377    2.429998   3564.653552  ...
# 1       0.904145     2.603965      1.175508    2.292886   3564.071577  ...
# 2       1.155864     2.293261      1.144330    2.107225   3564.207493  ...
# 3       1.143995     2.283394      1.008707    2.047132   3564.536023  ...
# 4       0.795261     1.726990      0.914162    1.746653   3565.157175  ...
#
#    F8 beta std  F8 beta m  AF4 delta std  AF4 delta m  AF4 theta std  \
# 0     0.991871   1.800747    3564.807696  2061.398768       1.839022
# 1     0.852802   1.620589    3565.004893  2061.989687       1.314281
# 2     1.075723   1.422287    3567.117563  2061.465328       1.628649
# 3     0.696173   1.416980    3565.482402  2060.885464       1.049679
# 4     0.743514   1.384104    3566.585859  2061.257282       1.500156
#
#    AF4 theta m  AF4 alpha std  AF4 alpha m  AF4 beta std  AF4 beta m
# 0     2.917284       1.095649     1.342387      1.141837    1.820216
# 1     2.876174       1.178849     1.939520      0.903631    2.145510
# 2     2.286765       1.591144     1.949241      1.006042    2.228659
# 3     2.486281       0.684482     2.173874      0.937085    2.165614
# 4     3.115490       1.235855     2.453826      0.840093    2.126146
#
# [5 rows x 113 columns]

# %%
ESR.loc[0:4,"AF3 delta std"] # to extract only the values of particular  section of the data set and particular coloum
# Out:
# 0    3566.375438
# 1    3565.986713
# 2    3566.977885
# 3    3566.342634
# 4    3567.798629
# Name: AF3 delta std, dtype: float64

# %%
ESR.loc[0:4,["AF3 delta std","AF3 delta m"]] # to extend the coloums
# Out:
#    AF3 delta std  AF3 delta m
# 0    3566.375438  2062.665095
# 1    3565.986713  2061.826341
# 2    3566.977885  2062.639807
# 3    3566.342634  2063.069909
# 4    3567.798629  2062.549327

# %%
# for the slicing the coloums based on the names
ESR.loc[0:4,"AF3 delta std":"AF3 alpha m"] # to extend the coloums
# Out:
#    AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  AF3 alpha std  \
# 0    3566.375438  2062.665095       1.040973     2.574824       1.376404
# 1    3565.986713  2061.826341       1.347088     2.154989       0.904145
# 2    3566.977885  2062.639807       1.083747     2.186981       1.155864
# 3    3566.342634  2063.069909       1.208843     2.160716       1.143995
# 4    3567.798629  2062.549327       1.378424     3.255706       0.795261
#
#    AF3 alpha m
# 0     1.657806
# 1     2.603965
# 2     2.293261
# 3     2.283394
# 4     1.726990

# %%
ESR.iloc[:,1] # iloc[rows,coloums]
# Out:
# 0       3566.375438
# 1       3565.986713
# 2       3566.977885
# 3       3566.342634
# 4       3567.798629
#            ...
# 2875    3572.183440
# 2876    3571.739312
# 2877    3571.184751
# 2878    3570.595817
# 2879    3570.330797
# Name: AF3 delta std, Length: 2880, dtype: float64

# %%
l = [1,2,3,4]
l[:3]
# Out:
# [1, 2, 3]

# %%
x = ESR.iloc[:,1:113].values #take the values of the x to train
x
x.shape
# Out:
# (2880, 112)

# %%
y = ESR.iloc[:,0].values
y
y.shape
y
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# # splitting the data set into test and train

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.4,random_state=0)

# %%
X_train
# Out:
# array([[3.56948347e+03, 2.06317915e+03, 8.99505753e-01, ...,
#         2.45685374e+00, 1.01082695e+00, 2.06291849e+00],
#        [3.57102871e+03, 2.06336548e+03, 7.16200015e-01, ...,
#         1.75016904e+00, 1.42801823e+00, 2.26716070e+00],
#        [3.57161078e+03, 2.06478178e+03, 1.11366691e+00, ...,
#         1.60157938e+00, 1.40369047e+00, 2.30152309e+00],
#        ...,
#        [3.56752209e+03, 2.06184332e+03, 1.29892853e+00, ...,
#         2.39447962e+00, 9.98580492e-01, 1.84395126e+00],
#        [3.57067985e+03, 2.06274991e+03, 7.35524947e-01, ...,
#         2.85278545e+00, 1.21785134e+00, 2.09177173e+00],
#        [3.56994168e+03, 2.06226434e+03, 1.45519505e+00, ...,
#         3.06599398e+00, 1.22725632e+00, 1.88207602e+00]])

# %%
X_test
# Out:
# array([[3.57013070e+03, 2.06368108e+03, 1.17090270e+00, ...,
#         3.35548345e+00, 1.21566513e+00, 2.49579623e+00],
#        [3.56939896e+03, 2.06504944e+03, 1.94064624e+00, ...,
#         2.37786600e+00, 9.39785992e-01, 2.00293032e+00],
#        [3.57202101e+03, 2.06358730e+03, 9.11703441e-01, ...,
#         1.53098819e+00, 1.17389800e+00, 2.01753390e+00],
#        ...,
#        [3.57524796e+03, 2.06489313e+03, 9.57588972e-01, ...,
#         1.52773057e+00, 1.17000037e+00, 2.05719369e+00],
#        [3.56884074e+03, 2.06272976e+03, 1.03606088e+00, ...,
#         2.85649889e+00, 1.22340762e+00, 2.34053441e+00],
#        [3.56760005e+03, 2.06268673e+03, 3.08768194e-01, ...,
#         2.13326867e+00, 7.09639458e-01, 1.95347267e+00]])

# %%
y_test
# Out:
# array([1., 0., 1., ..., 0., 2., 2.])

# %%
y_train
# Out:
# array([1., 2., 1., ..., 2., 2., 0.])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression
clf1 = LogisticRegression()
clf1.fit(X_train, y_train)
y_pred_log_reg = clf1.predict(X_test)


# Set regularization rate
reg = 1
# train a logistic regression model on the training set
model0 = LogisticRegression(C=0.1/reg, solver="liblinear").fit(X_train, y_train)

predictions0 = model0.predict(X_test)
print('Predicted labels: ', predictions0)
print('Actual labels:    ' ,y_test)
from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_test, predictions0)*100,'%')
# Out:
# Predicted labels:  [2. 0. 1. ... 2. 1. 2.]
# Actual labels:     [1. 0. 1. ... 0. 2. 2.]
# Accuracy: 54.77430555555556 %
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # logistic regression predictive model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
clf1 = LogisticRegression()
clf1.fit(X_train, y_train)
X_trainning_data_prediction = clf1.predict(X_train)

acc_log_reg = round(accuracy_score(X_trainning_data_prediction, y_train)*100,2)
print ('The testing accuracy due to logistic regression',str(acc_log_reg) + ' %')


X_test_data_prediction = clf1.predict(X_test)
acc_log_reg = round(accuracy_score(X_test_data_prediction, y_test)*100,2)
print ('The trainning accuracy',str(acc_log_reg) + ' %')


input_data = (3569.1645502276033,2063.8927540442164,1.6737259062456604,4.4447362906722345,0.5262086374136803,3.002088408715654,1.4250222149628013,3.3027389168677366,3563.80388774546,2060.239056808996,1.4040886882722885,2.279397625142047,1.2974008089347138,1.9600794414562057,0.7599563291241991,2.038976574144329,3709.0097120740693,2180.647682250679,19.491141388448067,39.84741942148074,20.493347999809618,41.2287964967144,46.00737210152773,73.49323257253741,3567.3652646503615,2062.4830972223294,1.2099963401875848,1.7718110277795354,0.16179325941076056,1.8184903572236792,0.6886717276621478,1.6417666169862315,3559.2192789568667,2057.363361163637,1.0275509554011428,2.5023887847525996,1.495156498646184,2.207700901706084,1.029114118297356,2.226548713744709,3677.92120815544,2159.747917973448,16.56418429067598,37.75394248650719,14.79399147039043,39.01913400137683,45.198246443440205,72.94291494925437,3574.9853368311283,2066.285516719386,1.024091979410101,2.980396263615955,0.9616119083522146,2.6522677130112546,3.595956730908903,5.876658118715367,3641.1855276249125,2147.591861938904,24.949741498558545,49.475072884767826,20.62595751977841,47.43664660378428,46.813504716231044,76.56728379426937,3579.2685387320844,2077.123468939235,3.607672368919065,9.938368917187017,4.343275036101095,12.528566017422637,17.19451664142212,27.690241735191368,3636.780856395662,2138.663492934993,19.3106698404085,36.20083571404867,15.881326556552738,38.774852645918465,43.60199502020086,69.778362729039,3694.245877472315,2174.777021196275,18.42652422355754

# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # support vector machines

# %%
#Support Vector Machine (SVM)
from sklearn.svm import SVC
clf2 = SVC()
clf2.fit(X_train, y_train)
y_pred_svc = clf2.predict(X_test)


#acc_svc =str(acc_svc )
# Set regularization rate
reg = 1
# train a support vector machine model on the training set
svm = SVC(kernel= 'linear', random_state=1, C=0.1)
svm.fit(X_train, y_train)

predictions1 = svm.predict(X_test)
print('Predicted labels: ', predictions1)
print('Actual labels:    ' ,y_test)
from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_test, predictions1)*100,'%')
# Out:
# Predicted labels:  [2. 0. 1. ... 2. 1. 1.]
# Actual labels:     [1. 0. 1. ... 0. 2. 2.]
# Accuracy: 55.729166666666664 %

# %% [markdown]
# # support vector machine predictive model

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
clf2 = SVC()
clf2.fit(X_train, y_train)
X_training_svm = clf2.predict(X_train)
acc_svm = round(accuracy_score(X_training_svm, y_train) * 100, 2)
print (' training Accuracy due to svm',str(acc_svm) + '%')

##### testing accuracy

X_test_svm_prediction = clf2.predict(X_test)
acc_svm = round(accuracy_score(X_test_svm_prediction, y_test)*100,2)
print ('testing Accuracy due to svm',str(acc_svm) + ' %')

# predicting system 


input_data1 = (3571.5776698564637,2063.503373184418,0.6029205352726208,2.967502905177528,1.4389885333016486,3.295020474122926,2.052318300662066,3.1929348458678626,3563.866619628976,2060.286630465621,1.2048099804200265,2.8103413736129825,0.27225772874660253,3.2862951557027094,1.0678356137575986,1.9728319154162408,3652.2514313778815,2127.7279583112304,13.27429161159918,34.36241292717517,36.26740246352244,56.93358683986829,48.214204584167035,74.47805088211938,3567.9662227438766,2061.7293157396007,0.5639959873004751,1.8721454702989053,1.4744399511095823,3.151339493976347,1.1046383080327566,1.9720318177527565,3557.726002755468,2055.8270423349927,0.891967376033974,2.669653114283589,1.5092077923923408,3.223965144639929,1.1366182390371824,2.1194584472732623,3629.0269092328194,2112.43573527682,13.547810600175742,33.42932882710743,32.38408386460878,56.56392200821375,46.852538109751684,75.99428250396319,3572.7670294266136,2064.8107935615335,1.1138945552313306,3.087238282060807,2.594065151630992,3.6937640590190437,3.743236375279487,5.449513343688413,3624.6588025440947,2117.797875892098,17.72209210101678,44.826561263290984,45.20186494044083,70.46932926197067,52.01336589318217,78.6992320452235,3574.8087842736973,2069.4394015495755,3.9431400426464016,10.523827732442765,9.784315414140655,16.80055893338254,16.40704563679004,29.77800027885906,3599.12334525423,2092.832289859586,10.32278916169577,31.94580621129784,27.862453555402396,51.41803859432595,42.988782306876445,69.05913364184316,3644.8426227370746,2124.2769771486005,13.791168423040311,35.1227944717199,35.803994796177,52.92858607598883,47.091113299675946,75.77059064746959,3574.582758813449,2065.692541804272,0.9280601508137211,2.6745293039707225,1.7775098800923772,3.4632397601696416,3.531847362428501,4.635422446750105,3612.975093711585,2106.3912922348186,10.486696520513933,34.594568511354616,31.14109960070707,57.91657781776544,46.74556734516573,76.699566475851,3687.0169057606745,2147.3154736112638,11.454735106178045,34.232922759264135,35.43148877248333,58.78652499474915,48.76385063044414,77.23551806293348)
input_data_as_numpy_array1 = np.asarray(input_data1)
#reshape the array as we predicting for one instance
input_data_reshape1 = input_data_as_numpy_array1.reshape(1,-1)

#standardize the input data
std_data1 = sc.transform(input_data_reshape1)
print(std_data1)

prediction1 = clf2.predict(std_data1)
print(prediction1)

if (prediction1[0] == 0):
    print("The person in thinking neutral")
elif (prediction1[0] == 1):
    print("The person is thinking right movement:")
elif(prediction1[0] == 2):
    print("The person is thinking left movement:")
# Out:
#  training Accuracy due to svm 90.91%
# testing Accuracy due to svm 76.65 %
# [[ 1.40848416e-01 -6.91420936e-02 -5.41651028e-01  2.49500009e-01
#    9.47792007e-01  1.13575089e+00  2.93024005e+00  2.61789085e+00
#   -1.33235677e-02  1.77196314e-01  4.53902125e-01  5.29792636e-01
#   -1.54183276e+00  1.61880981e+00  1.22722900e-01 -2.16933177e-01
#    5.06379276e+01  3.92974384e+01  2.55791901e+01  4.03203017e+01
#    8.49030527e+01  7.57866824e+01  1.57909583e+02  1.38283856e+02
#    3.19173662e-01 -2.69718569e-02 -4.79487954e-01 -1.62090886e-01
#    1.62202136e+00  1.47942718e+00  7.79657372e-01  4.61693641e-01
#   -4.50697217e-01 -3.27235218e-01  4.40499813e-01  1.20525911e+00
#    2.17453711e+00  2.24953844e+00  1.21326244e+00  1.00058542e+00
#    9.33795589e+00  1.40094300e+01  2.54919660e+01  3.77632806e+01
#    7.06343571e+01  7.56658936e+01  1.70446481e+02  1.69900438e+02
#    5.09412096e+00  2.90035725e+00  5.33412686e-01  1.22461341e+00
#    4.29854493e+00  2.39804028e+00  1.14850114e+01  8.34714818e+00
#    1.51230495e+01  2.33216500e+01  4.52062764e+01  6.50100905e+01
#    1.44249571e+02  1.23274865e+02  2.16363609e+02  1.67448895e+02
#   -1.02231477e-02 -6.15186863e-02  4.37065174e+00  4.14185770e+00
#    1.93992129e+01  1.21643046e+01  5.31221560e+01  4.50474177e+01
#    2.66892739e+00  3.55602693e+00  1.47855681e+01  2.36138171e+01
#    5.84741964e+01  5.19082207e+01  1.17461597e+02  9.95235949e+01
#    2.67946603e+01  1.98540755e+01  1.42596981e+01  1.91075618e+01
#    7.42211464e+01  6.13749625e+01  1.99815780e+02  1.97039522e+02
#    1.22870465e-03 -6.19017802e-01 -7.37815807e-01 -6.22568782e-01
#    6.81377356e-01  6.01384542e-02  5.49360568e+00  2.69624418e+00
#    1.46145979e+00  2.45005266e+00  1.11710763e+01  1.87891902e+01
#    6.70945770e+01  6.78008706e+01  1.72491676e+02  2.21447560e+02
#    4.39039895e+01  2.60837517e+01  1.15818411e+01  1.92300621e+01
#    7.60582153e+01  7.34764852e+01  2.16696098e+02  2.63218600e+02]]
# [0.]
# The person in thinking neutral

# %% [markdown]
# # k nearest neighbors

# %%
#k-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
clf3 = KNeighborsClassifier()
clf3.fit(X_train, y_train)
y_pred_knn = clf3.predict(X_test)


from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
predictions2 =classifier.predict(X_test)
print('Predicted labels: ', predictions2)
print('Actual labels:    ' ,y_test)
from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_test, predictions2)*100,'%')
# Out:
# Predicted labels:  [2. 0. 0. ... 0. 0. 2.]
# Actual labels:     [1. 0. 1. ... 0. 2. 2.]
# Accuracy: 83.15972222222221 %

# %% [markdown]
# # k  nearest neighbors predictive model

# %%
from sklearn.neighbors import KNeighborsClassifier
clf3 = KNeighborsClassifier()
clf3.fit(X_train, y_train)
X_training_knn = clf3.predict(X_train)
acc_knn = round(accuracy_score(X_training_knn, y_train) * 100, 2)
print ('training  accuracy due to k-nearest neighbors',str(acc_knn)+'%')

X_test_knn_prediction = clf3.predict(X_test)
acc_knn = round(accuracy_score(X_test_knn_prediction, y_test)*100,2)
print ('Testing accuracy due to k-nearest neighbors',str(acc_knn) + ' %')


input_data2 = (3571.5776698564637,2063.503373184418,0.6029205352726208,2.967502905177528,1.4389885333016486,3.295020474122926,2.052318300662066,3.1929348458678626,3563.866619628976,2060.286630465621,1.2048099804200265,2.8103413736129825,0.27225772874660253,3.2862951557027094,1.0678356137575986,1.9728319154162408,3652.2514313778815,2127.7279583112304,13.27429161159918,34.36241292717517,36.26740246352244,56.93358683986829,48.214204584167035,74.47805088211938,3567.9662227438766,2061.7293157396007,0.5639959873004751,1.8721454702989053,1.4744399511095823,3.151339493976347,1.1046383080327566,1.9720318177527565,3557.726002755468,2055.8270423349927,0.891967376033974,2.669653114283589,1.5092077923923408,3.223965144639929,1.1366182390371824,2.1194584472732623,3629.0269092328194,2112.43573527682,13.547810600175742,33.42932882710743,32.38408386460878,56.56392200821375,46.852538109751684,75.99428250396319,3572.7670294266136,2064.8107935615335,1.1138945552313306,3.087238282060807,2.594065151630992,3.6937640590190437,3.743236375279487,5.449513343688413,3624.6588025440947,2117.797875892098,17.72209210101678,44.826561263290984,45.20186494044083,70.46932926197067,52.01336589318217,78.6992320452235,3574.8087842736973,2069.4394015495755,3.9431400426464016,10.523827732442765,9.784315414140655,16.80055893338254,16.40704563679004,29.77800027885906,3599.12334525423,2092.832289859586,10.32278916169577,31.94580621129784,27.862453555402396,51.41803859432595,42.988782306876445,69.05913364184316,3644.8426227370746,2124.2769771486005,13.791168423040311,35.1227944717199,35.803994796177,52.92858607598883,47.091113299675946,75.77059064746959,3574.582758813449,2065.692541804272,0.9280601508137211,2.6745293039707225,1.7775098800923772,3.4632397601696416,3.531847362428501,4.635422446750105,3612.975093711585,2106.3912922348186,10.486696520513933,34.594568511354616,31.14109960070707,57.91657781776544,46.74556734516573,76.699566475851,3687.0169057606745,2147.3154736112638,11.454735106178045,34.232922759264135,35.43148877248333,58.78652499474915,48.76385063044414,77.23551806293348)
input_data_as_numpy_array2 = np.asarray(input_data2)
#reshape the array as we predicting for one instance
input_data_reshape2 = input_data_as_numpy_array2.reshape(1,-1)

#standardize the input data
std_data2 = sc.transform(input_data_reshape2)
print(std_data2)

prediction2 = clf3.predict(std_data2)
print(prediction2)

if (prediction2[0] == 0):
    print("The person in thinking neutral")
elif (prediction2[0] == 1):
    print("The person is thinking right movement:")
elif(prediction2[0] == 2):
    print("The person is thinking left movement:")
# Out:
# training  accuracy due to k-nearest neighbors 93.34%
# Testing accuracy due to k-nearest neighbors 83.16 %
# [[ 1.40848416e-01 -6.91420936e-02 -5.41651028e-01  2.49500009e-01
#    9.47792007e-01  1.13575089e+00  2.93024005e+00  2.61789085e+00
#   -1.33235677e-02  1.77196314e-01  4.53902125e-01  5.29792636e-01
#   -1.54183276e+00  1.61880981e+00  1.22722900e-01 -2.16933177e-01
#    5.06379276e+01  3.92974384e+01  2.55791901e+01  4.03203017e+01
#    8.49030527e+01  7.57866824e+01  1.57909583e+02  1.38283856e+02
#    3.19173662e-01 -2.69718569e-02 -4.79487954e-01 -1.62090886e-01
#    1.62202136e+00  1.47942718e+00  7.79657372e-01  4.61693641e-01
#   -4.50697217e-01 -3.27235218e-01  4.40499813e-01  1.20525911e+00
#    2.17453711e+00  2.24953844e+00  1.21326244e+00  1.00058542e+00
#    9.33795589e+00  1.40094300e+01  2.54919660e+01  3.77632806e+01
#    7.06343571e+01  7.56658936e+01  1.70446481e+02  1.69900438e+02
#    5.09412096e+00  2.90035725e+00  5.33412686e-01  1.22461341e+00
#    4.29854493e+00  2.39804028e+00  1.14850114e+01  8.34714818e+00
#    1.51230495e+01  2.33216500e+01  4.52062764e+01  6.50100905e+01
#    1.44249571e+02  1.23274865e+02  2.16363609e+02  1.67448895e+02
#   -1.02231477e-02 -6.15186863e-02  4.37065174e+00  4.14185770e+00
#    1.93992129e+01  1.21643046e+01  5.31221560e+01  4.50474177e+01
#    2.66892739e+00  3.55602693e+00  1.47855681e+01  2.36138171e+01
#    5.84741964e+01  5.19082207e+01  1.17461597e+02  9.95235949e+01
#    2.67946603e+01  1.98540755e+01  1.42596981e+01  1.91075618e+01
#    7.42211464e+01  6.13749625e+01  1.99815780e+02  1.97039522e+02
#    1.22870465e-03 -6.19017802e-01 -7.37815807e-01 -6.22568782e-01
#    6.81377356e-01  6.01384542e-02  5.49360568e+00  2.69624418e+00
#    1.46145979e+00  2.45005266e+00  1.11710763e+01  1.87891902e+01
#    6.70945770e+01  6.78008706e+01  1.72491676e+02  2.21447560e+02
#    4.39039895e+01  2.60837517e+01  1.15818411e+01  1.92300621e+01
#    7.60582153e+01  7.34764852e+01  2.16696098e+02  2.63218600e+02]]
# [1.]
# The person is thinking right movement:

# %%
# !pip install --upgrade tabulate
# Out:
# Requirement already satisfied: tabulate in c:\users\user\anaconda3\lib\site-packages (0.8.10)

# %%
# !pip install --upgrade simple_colors
# Out:
# Requirement already satisfied: simple_colors in c:\users\user\anaconda3\lib\site-packages (0.1.5)

# %%
# import module
from tabulate import tabulate
from simple_colors import *
# assign data
mydata = [
[black('K NEAREST NEIGHBORS','bold'),black(accuracy_score(y_test, predictions2)*100,'bold')],
[black('SUPPORT VECTOR MACHINES','bold'),black(accuracy_score(y_test, predictions1)*100,'bold')],
[black('LOGISTIC REGRESSION','bold'),black(accuracy_score(y_test, predictions0)*100,'bold')]
]

# create header

head = [(red('Classifier','bold')),(red('Accuracy(%)','bold')),'\033[1m']
'Accuracy(%)'
# display table
print(tabulate(mydata, headers=head, tablefmt="grid"))
# Out:
# +-------------------------+---------------+
# | Classifier              |   Accuracy(%) |
# +=========================+===============+
# | K NEAREST NEIGHBORS     |       83.1597 |
# +-------------------------+---------------+
# | SUPPORT VECTOR MACHINES |       55.7292 |
# +-------------------------+---------------+
# | LOGISTIC REGRESSION     |       54.7743 |
# +-------------------------+---------------+
