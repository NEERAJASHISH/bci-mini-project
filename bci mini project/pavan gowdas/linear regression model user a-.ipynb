# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

# %%
ESR = pd.read_csv('user_a.csv')
ESR.head()
# Out:
#    Class  AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  \
# 0    1.0    3569.164550  2063.892754       1.673726     4.444736
# 1    1.0    3568.423670  2063.099248       1.897790     3.728823
# 2    1.0    3568.157929  2062.445859       2.798014     2.574504
# 3    1.0    3567.710021  2062.112673       2.181775     3.610507
# 4    1.0    3565.546124  2063.128867       1.685161     3.384311
#
#    AF3 alpha std  AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  ...  \
# 0       0.526209     3.002088      1.425022    3.302739   3563.803888  ...
# 1       1.304186     1.854353      1.366575    2.546458   3563.560922  ...
# 2       1.120537     1.958819      0.982433    2.258622   3563.279981  ...
# 3       0.629608     2.155876      0.856275    2.233711   3562.787801  ...
# 4       0.677526     1.795798      0.927924    1.909810   3562.655091  ...
#
#    F8 beta std  F8 beta m  AF4 delta std  AF4 delta m  AF4 theta std  \
# 0    45.468326  72.508750    3701.186330  2182.676835      18.192418
# 1    36.551948  66.931186    3725.210509  2180.197439       8.820788
# 2    40.754308  66.816547    3724.417296  2176.823208      18.159202
# 3    38.074628  63.915386    3725.822160  2177.089059      19.737616
# 4    35.357384  64.534645    3723.053978  2167.798335       8.429414
#
#    AF4 theta m  AF4 alpha std  AF4 alpha m  AF4 beta std  AF4 beta m
# 0    41.349662      16.004756    42.046467     46.280843   73.565719
# 1    38.012788      19.601233    29.431054     38.559351   67.470041
# 2    23.612639      14.378291    19.555084     43.210004   67.781924
# 3    29.484396      15.793034    25.713513     39.250246   65.031031
# 4    26.374975      14.920736    35.675266     33.901687   66.956313
#
# [5 rows x 113 columns]

# %%
ESR
# Out:
#       Class  AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  \
# 0       1.0    3569.164550  2063.892754       1.673726     4.444736
# 1       1.0    3568.423670  2063.099248       1.897790     3.728823
# 2       1.0    3568.157929  2062.445859       2.798014     2.574504
# 3       1.0    3567.710021  2062.112673       2.181775     3.610507
# 4       1.0    3565.546124  2063.128867       1.685161     3.384311
# ...     ...            ...          ...            ...          ...
# 2875    0.0    3572.820630  2064.823341       0.676923     1.620879
# 2876    0.0    3573.915291  2065.845542       0.860279     1.504333
# 2877    0.0    3574.326202  2066.031013       1.416731     2.581577
# 2878    0.0    3573.735788  2065.945333       1.119943     2.769816
# 2879    0.0    3573.982930  2065.960401       1.011062     2.696217
#
#       AF3 alpha std  AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  ...  \
# 0          0.526209     3.002088      1.425022    3.302739   3563.803888  ...
# 1          1.304186     1.854353      1.366575    2.546458   3563.560922  ...
# 2          1.120537     1.958819      0.982433    2.258622   3563.279981  ...
# 3          0.629608     2.155876      0.856275    2.233711   3562.787801  ...
# 4          0.677526     1.795798      0.927924    1.909810   3562.655091  ...
# ...             ...          ...           ...         ...           ...  ...
# 2875       0.965369     2.392263      2.582266    3.185588   3565.166724  ...
# 2876       0.539180     1.331165      2.533695    2.870270   3565.734750  ...
# 2877       0.715012     1.307975      2.261013    2.873613   3567.582880  ...
# 2878       0.455408     1.541430      1.782814    3.067384   3567.857997  ...
# 2879       1.021707     2.086820      1.922342    2.675613   3568.222662  ...
#
#       F8 beta std  F8 beta m  AF4 delta std  AF4 delta m  AF4 theta std  \
# 0       45.468326  72.508750    3701.186330  2182.676835      18.192418
# 1       36.551948  66.931186    3725.210509  2180.197439       8.820788
# 2       40.754308  66.816547    3724.417296  2176.823208      18.159202
# 3       38.074628  63.915386    3725.822160  2177.089059      19.737616
# 4       35.357384  64.534645    3723.053978  2167.798335       8.429414
# ...           ...        ...            ...          ...            ...
# 2875    26.247669  13.320391    3607.467804  2089.263161       1.605773
# 2876    26.120266  14.809811    3613.165565  2089.298802       0.643899
# 2877    26.513829  16.084048    3615.755534  2094.482958       1.851314
# 2878    20.049092  21.248860    3620.821019  2097.450420       5.035767
# 2879    19.210888  22.058247    3620.970803  2096.125026       4.120981
#
#       AF4 theta m  AF4 alpha std  AF4 alpha m  AF4 beta std  AF4 beta m
# 0       41.349662      16.004756    42.046467     46.280843   73.565719
# 1       38.012788      19.601233    29.431054     38.559351   67.470041
# 2       23.612639      14.378291    19.555084     43.210004   67.781924
# 3       29.484396      15.793034    25.713513     39.250246   65.031031
# 4       26.374975      14.920736    35.675266     33.901687   66.956313
# ...           ...            ...          ...           ...         ...
# 2875     4.247634       1.649762     2.938868     31.019482   16.648758
# 2876     6.903858       1.287563     3.942647     31.546882   17.429113
# 2877     5.683580       2.411642     6.355117     32.238063   19.023897
# 2878    12.027902       6.441267    14.663681     24.109509   26.468254
# 2879    12.124434       7.613556    12.998119     23.635052   26.581116
#
# [2880 rows x 113 columns]

# %%
ESR.columns
# Out:
# Index(['Class', 'AF3 delta std', 'AF3 delta m', 'AF3 theta std', 'AF3 theta m',
#        'AF3 alpha std', 'AF3 alpha m', 'AF3 beta std', 'AF3 beta m',
#        'F7 delta std',
#        ...
#        'F8 beta std', 'F8 beta m', 'AF4 delta std', 'AF4 delta m',
#        'AF4 theta std', 'AF4 theta m', 'AF4 alpha std', 'AF4 alpha m',
#        'AF4 beta std', 'AF4 beta m'],
#       dtype='object', length=113)

# %%
ESR.isnull().sum()  #isnull().sum()  gives the sum of missing value in the data set or  nan values here in the data set
# Out:
# Class            0
# AF3 delta std    0
# AF3 delta m      0
# AF3 theta std    0
# AF3 theta m      0
#                 ..
# AF4 theta m      0
# AF4 alpha std    0
# AF4 alpha m      0
# AF4 beta std     0
# AF4 beta m       0
# Length: 113, dtype: int64

# %%
ESR.info() # gives the information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Columns: 113 entries, Class to AF4 beta m
# dtypes: float64(113)
# memory usage: 2.5 MB

# %%
ESR.tail(2881) #gives the entire description of the data set
# Out:
#       Class  AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  \
# 0       1.0    3569.164550  2063.892754       1.673726     4.444736
# 1       1.0    3568.423670  2063.099248       1.897790     3.728823
# 2       1.0    3568.157929  2062.445859       2.798014     2.574504
# 3       1.0    3567.710021  2062.112673       2.181775     3.610507
# 4       1.0    3565.546124  2063.128867       1.685161     3.384311
# ...     ...            ...          ...            ...          ...
# 2875    0.0    3572.820630  2064.823341       0.676923     1.620879
# 2876    0.0    3573.915291  2065.845542       0.860279     1.504333
# 2877    0.0    3574.326202  2066.031013       1.416731     2.581577
# 2878    0.0    3573.735788  2065.945333       1.119943     2.769816
# 2879    0.0    3573.982930  2065.960401       1.011062     2.696217
#
#       AF3 alpha std  AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  ...  \
# 0          0.526209     3.002088      1.425022    3.302739   3563.803888  ...
# 1          1.304186     1.854353      1.366575    2.546458   3563.560922  ...
# 2          1.120537     1.958819      0.982433    2.258622   3563.279981  ...
# 3          0.629608     2.155876      0.856275    2.233711   3562.787801  ...
# 4          0.677526     1.795798      0.927924    1.909810   3562.655091  ...
# ...             ...          ...           ...         ...           ...  ...
# 2875       0.965369     2.392263      2.582266    3.185588   3565.166724  ...
# 2876       0.539180     1.331165      2.533695    2.870270   3565.734750  ...
# 2877       0.715012     1.307975      2.261013    2.873613   3567.582880  ...
# 2878       0.455408     1.541430      1.782814    3.067384   3567.857997  ...
# 2879       1.021707     2.086820      1.922342    2.675613   3568.222662  ...
#
#       F8 beta std  F8 beta m  AF4 delta std  AF4 delta m  AF4 theta std  \
# 0       45.468326  72.508750    3701.186330  2182.676835      18.192418
# 1       36.551948  66.931186    3725.210509  2180.197439       8.820788
# 2       40.754308  66.816547    3724.417296  2176.823208      18.159202
# 3       38.074628  63.915386    3725.822160  2177.089059      19.737616
# 4       35.357384  64.534645    3723.053978  2167.798335       8.429414
# ...           ...        ...            ...          ...            ...
# 2875    26.247669  13.320391    3607.467804  2089.263161       1.605773
# 2876    26.120266  14.809811    3613.165565  2089.298802       0.643899
# 2877    26.513829  16.084048    3615.755534  2094.482958       1.851314
# 2878    20.049092  21.248860    3620.821019  2097.450420       5.035767
# 2879    19.210888  22.058247    3620.970803  2096.125026       4.120981
#
#       AF4 theta m  AF4 alpha std  AF4 alpha m  AF4 beta std  AF4 beta m
# 0       41.349662      16.004756    42.046467     46.280843   73.565719
# 1       38.012788      19.601233    29.431054     38.559351   67.470041
# 2       23.612639      14.378291    19.555084     43.210004   67.781924
# 3       29.484396      15.793034    25.713513     39.250246   65.031031
# 4       26.374975      14.920736    35.675266     33.901687   66.956313
# ...           ...            ...          ...           ...         ...
# 2875     4.247634       1.649762     2.938868     31.019482   16.648758
# 2876     6.903858       1.287563     3.942647     31.546882   17.429113
# 2877     5.683580       2.411642     6.355117     32.238063   19.023897
# 2878    12.027902       6.441267    14.663681     24.109509   26.468254
# 2879    12.124434       7.613556    12.998119     23.635052   26.581116
#
# [2880 rows x 113 columns]

# %%
ESR.loc[3] # it fetches the particular row  loc[row number]
# Out:
# Class               1.000000
# AF3 delta std    3567.710021
# AF3 delta m      2062.112673
# AF3 theta std       2.181775
# AF3 theta m         3.610507
#                     ...
# AF4 theta m        29.484396
# AF4 alpha std      15.793034
# AF4 alpha m        25.713513
# AF4 beta std       39.250246
# AF4 beta m         65.031031
# Name: 3, Length: 113, dtype: float64

# %%
ESR.loc[3,"AF3 delta std"]
# Out:
# 3567.7100207417207

# %%
ESR.loc[0:4] # to extract the particular portion of the data set
# Out:
#    Class  AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  \
# 0    1.0    3569.164550  2063.892754       1.673726     4.444736
# 1    1.0    3568.423670  2063.099248       1.897790     3.728823
# 2    1.0    3568.157929  2062.445859       2.798014     2.574504
# 3    1.0    3567.710021  2062.112673       2.181775     3.610507
# 4    1.0    3565.546124  2063.128867       1.685161     3.384311
#
#    AF3 alpha std  AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  ...  \
# 0       0.526209     3.002088      1.425022    3.302739   3563.803888  ...
# 1       1.304186     1.854353      1.366575    2.546458   3563.560922  ...
# 2       1.120537     1.958819      0.982433    2.258622   3563.279981  ...
# 3       0.629608     2.155876      0.856275    2.233711   3562.787801  ...
# 4       0.677526     1.795798      0.927924    1.909810   3562.655091  ...
#
#    F8 beta std  F8 beta m  AF4 delta std  AF4 delta m  AF4 theta std  \
# 0    45.468326  72.508750    3701.186330  2182.676835      18.192418
# 1    36.551948  66.931186    3725.210509  2180.197439       8.820788
# 2    40.754308  66.816547    3724.417296  2176.823208      18.159202
# 3    38.074628  63.915386    3725.822160  2177.089059      19.737616
# 4    35.357384  64.534645    3723.053978  2167.798335       8.429414
#
#    AF4 theta m  AF4 alpha std  AF4 alpha m  AF4 beta std  AF4 beta m
# 0    41.349662      16.004756    42.046467     46.280843   73.565719
# 1    38.012788      19.601233    29.431054     38.559351   67.470041
# 2    23.612639      14.378291    19.555084     43.210004   67.781924
# 3    29.484396      15.793034    25.713513     39.250246   65.031031
# 4    26.374975      14.920736    35.675266     33.901687   66.956313
#
# [5 rows x 113 columns]

# %%
ESR.loc[0:4,"AF3 delta std"] # to extract only the values of particular  section of the data set and particular coloum
# Out:
# 0    3569.164550
# 1    3568.423670
# 2    3568.157929
# 3    3567.710021
# 4    3565.546124
# Name: AF3 delta std, dtype: float64

# %%
ESR.loc[0:4,["AF3 delta std","AF3 delta m"]] # to extend the coloums
# Out:
#    AF3 delta std  AF3 delta m
# 0    3569.164550  2063.892754
# 1    3568.423670  2063.099248
# 2    3568.157929  2062.445859
# 3    3567.710021  2062.112673
# 4    3565.546124  2063.128867

# %%
# for the slicing the coloums based on the names
ESR.loc[0:4,"AF3 delta std":"AF3 alpha m"] # to extend the coloums
# Out:
#    AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  AF3 alpha std  \
# 0    3569.164550  2063.892754       1.673726     4.444736       0.526209
# 1    3568.423670  2063.099248       1.897790     3.728823       1.304186
# 2    3568.157929  2062.445859       2.798014     2.574504       1.120537
# 3    3567.710021  2062.112673       2.181775     3.610507       0.629608
# 4    3565.546124  2063.128867       1.685161     3.384311       0.677526
#
#    AF3 alpha m
# 0     3.002088
# 1     1.854353
# 2     1.958819
# 3     2.155876
# 4     1.795798

# %%
ESR.iloc[:,1] # iloc[rows,coloums]
# Out:
# 0       3569.164550
# 1       3568.423670
# 2       3568.157929
# 3       3567.710021
# 4       3565.546124
#            ...
# 2875    3572.820630
# 2876    3573.915291
# 2877    3574.326202
# 2878    3573.735788
# 2879    3573.982930
# Name: AF3 delta std, Length: 2880, dtype: float64

# %%
l = [1,2,3,4]
l[:3]
# Out:
# [1, 2, 3]

# %%
x = ESR.iloc[:,1:113].values #take the values of the x to train
x
x.shape
# Out:
# (2880, 112)

# %%
y = ESR.iloc[:,0].values
y
y.shape
y
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %% [markdown]
# # splitting the data set into test and train

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.4,random_state=0)

# %%
X_train
# Out:
# array([[3.57117491e+03, 2.06436255e+03, 1.51874602e+00, ...,
#         2.41254298e+01, 2.12617309e+01, 3.87207238e+01],
#        [3.57415462e+03, 2.06522948e+03, 1.52573778e+00, ...,
#         7.12421924e+00, 3.53609399e+01, 1.98045560e+01],
#        [3.57184269e+03, 2.06505550e+03, 1.31052908e+00, ...,
#         4.03435113e+01, 3.39436414e+01, 5.29638116e+01],
#        ...,
#        [3.57486351e+03, 2.06590684e+03, 1.35336738e+00, ...,
#         8.68251156e+00, 3.55012520e+01, 2.96547964e+01],
#        [3.57287323e+03, 2.06399630e+03, 2.04662830e+00, ...,
#         7.95205727e+00, 3.35529189e+01, 1.91060034e+01],
#        [3.57318626e+03, 2.06445202e+03, 4.48625441e-01, ...,
#         1.69092966e+01, 2.30460812e+01, 3.06892648e+01]])

# %%
X_test
# Out:
# array([[3.57266895e+03, 2.06442576e+03, 7.00105988e-01, ...,
#         8.85405014e+00, 5.70580449e+01, 3.30533653e+01],
#        [3.57544765e+03, 2.06597371e+03, 7.61767438e-01, ...,
#         1.03058434e+01, 3.92314311e+01, 2.71089612e+01],
#        [3.57374340e+03, 2.06473700e+03, 6.81163874e-01, ...,
#         1.15353676e+01, 3.39159994e+01, 2.31209811e+01],
#        ...,
#        [3.57241940e+03, 2.06390025e+03, 4.64999250e-01, ...,
#         3.06334966e+01, 3.94139421e+01, 4.34565856e+01],
#        [3.57331915e+03, 2.06448907e+03, 5.80886485e-01, ...,
#         7.52830763e+00, 3.57951577e+01, 1.96736949e+01],
#        [3.57443299e+03, 2.06563445e+03, 7.57122535e-01, ...,
#         7.99928784e+00, 3.26315537e+01, 1.85151341e+01]])

# %%
y_test
# Out:
# array([1., 0., 1., ..., 0., 2., 2.])

# %%
y_train
# Out:
# array([1., 2., 1., ..., 2., 2., 0.])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression
clf1 = LogisticRegression(multi_class='multinomial', solver='lbfgs')
clf1.fit(X_train, y_train)
y_pred_log_reg = clf1.predict(X_test)


# Set regularization rate
reg = 1
# train a logistic regression model on the training set
model0 = LogisticRegression(C=0.1/reg, solver="liblinear").fit(X_train, y_train)

predictions0 = model0.predict(X_test)
print('Predicted labels: ', predictions0)
print('Actual labels:    ' ,y_test)
from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_test, predictions0)*100,'%')
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Predicted labels:  [0. 0. 0. ... 0. 2. 2.]
# Actual labels:     [1. 0. 1. ... 0. 2. 2.]
# Accuracy: 59.201388888888886 %

# %% [markdown]
# # logistic regression predictive model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
clf1 = LogisticRegression()
clf1.fit(X_train, y_train)
X_trainning_data_prediction = clf1.predict(X_train)

acc_log_reg = round(accuracy_score(X_trainning_data_prediction, y_train)*100,2)
print ('The testing accuracy due to logistic regression',str(acc_log_reg) + ' %')


X_test_data_prediction = clf1.predict(X_test)
acc_log_reg = round(accuracy_score(X_test_data_prediction, y_test)*100,2)
print ('The trainning accuracy',str(acc_log_reg) + ' %')


input_data = (3569.1645502276033,2063.8927540442164,1.6737259062456604,4.4447362906722345,0.5262086374136803,3.002088408715654,1.4250222149628013,3.3027389168677366,3563.80388774546,2060.239056808996,1.4040886882722885,2.279397625142047,1.2974008089347138,1.9600794414562057,0.7599563291241991,2.038976574144329,3709.0097120740693,2180.647682250679,19.491141388448067,39.84741942148074,20.493347999809618,41.2287964967144,46.00737210152773,73.49323257253741,3567.3652646503615,2062.4830972223294,1.2099963401875848,1.7718110277795354,0.16179325941076056,1.8184903572236792,0.6886717276621478,1.6417666169862315,3559.2192789568667,2057.363361163637,1.0275509554011428,2.5023887847525996,1.495156498646184,2.207700901706084,1.029114118297356,2.226548713744709,3677.92120815544,2159.747917973448,16.56418429067598,37.75394248650719,14.79399147039043,39.01913400137683,45.198246443440205,72.94291494925437,3574.9853368311283,2066.285516719386,1.024091979410101,2.980396263615955,0.9616119083522146,2.6522677130112546,3.595956730908903,5.876658118715367,3641.1855276249125,2147.591861938904,24.949741498558545,49.475072884767826,20.62595751977841,47.43664660378428,46.813504716231044,76.56728379426937,3579.2685387320844,2077.123468939235,3.607672368919065,9.938368917187017,4.343275036101095,12.528566017422637,17.19451664142212,27.690241735191368,3636.780856395662,2138.663492934993,19.3106698404085,36.20083571404867,15.881326556552738,38.774852645918465,43.60199502020086,69.778362729039,3694.245877472315,2174.777021196275,18.42652422355754,40.4883929319332,16.41050498199057,38.85033552451535,45.32926324514407,72.90779981468211,3577.5214338152978,2067.996961866034,1.2329730962348122,3.073659235927023,0.9194189952153057,2.634124325509432,3.3486977417075225,5.380652423380749,3665.336755373622,2157.675046311957,15.543111488507492,37.37419935494729,15.907311987132736,40.854795335375655,45.468325549548254,72.50874980453948,3701.186330401986,2182.676835001596,18.19241807455738,41.349662145306006,16.004755565937725,42.04646727404781,46.2808430260123,73.5657188422982)
input_data_as_numpy_array = np.asarray(input_data)
#reshape the array as we predicting for one instance
input_data_reshape = input_data_as_numpy_array.reshape(1,-1)

#standardize the input data
std_data = sc.transform(input_data_reshape)
print(std_data)

prediction = clf1.predict(std_data)
print(prediction)

if (prediction[0] == 0):
    print("The person in thinking neutral")
elif (prediction[0] == 1):
    print("The person is thinking right movement:")
elif(prediction[0] == 2):
    print("The person is thinking left movement:")
# Out:
# The testing accuracy due to logistic regression 69.33 %
# The trainning accuracy 60.76 %
# [[-1.62356341e+00 -8.59178646e-01  1.33699670e+00  2.05167696e+00
#   -9.61620953e-01  9.00363638e-01 -1.40706351e+00 -1.04009195e-02
#   -1.70502090e+00 -1.07201917e+00  1.17704321e+00  1.30308521e-01
#    9.57805442e-01 -3.49378116e-01 -1.62786155e+00 -6.08316183e-01
#    2.65641809e+00  1.94043482e+00  2.23532007e+00  1.28112645e+00
#    2.03410550e+00  1.57807696e+00  4.67837168e-01  2.20948737e+00
#    1.71505448e+00  2.04018373e+00  1.26908305e+00  2.05220395e-03
#   -1.56481866e+00  3.70220718e-02 -1.08075222e+00 -5.32983293e-01
#   -8.29164094e-01 -4.20609990e-01  6.03142756e-01  9.19758400e-01
#    1.21359246e+00  8.14024193e-02  9.47594939e-02  7.70589149e-01
#    2.49068310e+00  2.00801169e+00  2.25502244e+00  1.60500293e+00
#    1.47648691e+00  1.90442081e+00  7.62780891e-01  2.72853707e+00
#    9.05436271e-01  6.06434746e-01 -1.50306733e-01  4.66818724e-01
#   -4.80628303e-01 -2.94214123e-01 -7.40741052e-01  4.05864088e-01
#    2.13036054e+00  1.73409788e+00  3.02480727e+00  1.73156435e+00
#    2.63965334e+00  2.33387159e+00  1.22107382e+00  2.87977501e+00
#   -1.15741882e+00  5.43680600e-02  1.14164858e+00  1.36772354e+00
#    9.94316650e-01  1.72188574e+00  1.00105339e+00  2.75320509e+00
#    1.68860599e+00  1.81004369e+00  3.97142048e+00  2.07095156e+00
#    2.53351020e+00  2.81285897e+00  1.46254092e+00  3.74167676e+00
#    2.38096304e+00  1.91084046e+00  2.24287917e+00  1.50541349e+00
#    1.55356613e+00  1.61314900e+00  5.68155182e-01  2.49727782e+00
#    7.03020238e-02 -1.18411548e-01 -2.37137527e-01 -1.75953598e-01
#   -5.43773544e-01 -3.38875531e-01 -1.85598678e-01  2.93633981e-01
#    1.23120371e+00  1.51384928e+00  2.28031649e+00  1.77679729e+00
#    1.96087418e+00  2.36773557e+00  1.05998381e+00  3.04385112e+00
#    2.51286272e+00  2.23908607e+00  2.31495926e+00  1.73190592e+00
#    1.48764944e+00  1.95039499e+00  6.37472331e-01  2.43308856e+00]]
# [1.]
# The person is thinking right movement:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # support vector machines

# %%
#Support Vector Machine (SVM)
from sklearn.svm import SVC
clf2 = SVC()
clf2.fit(X_train, y_train)
y_pred_svc = clf2.predict(X_test)


#acc_svc =str(acc_svc )
# Set regularization rate
reg = 1
# train a support vector machine model on the training set
svm = SVC(kernel= 'linear', random_state=1, C=0.1)
svm.fit(X_train, y_train)

predictions1 = svm.predict(X_test)
print('Predicted labels: ', predictions1)
print('Actual labels:    ' ,y_test)
from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_test, predictions1)*100,'%')
# Out:
# Predicted labels:  [0. 0. 0. ... 0. 0. 2.]
# Actual labels:     [1. 0. 1. ... 0. 2. 2.]
# Accuracy: 59.635416666666664 %

# %% [markdown]
# # support vector machine predictive model

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
clf2 = SVC()
clf2.fit(X_train, y_train)
X_training_svm = clf2.predict(X_train)
acc_svm = round(accuracy_score(X_training_svm, y_train) * 100, 2)
print (' training Accuracy due to svm',str(acc_svm) + '%')

##### testing accuracy

X_test_svm_prediction = clf2.predict(X_test)
acc_svm = round(accuracy_score(X_test_svm_prediction, y_test)*100,2)
print ('testing Accuracy due to svm',str(acc_svm) + ' %')

# predicting system 


input_data1 = (3574.6537759451617,2066.330699389898,0.6453717582899121,1.3530433667789934,0.8683861059701232,2.355776507649864,2.7161997718747073,2.9343384398823797,3571.8253801325905,2063.386738321239,1.4998455114259621,2.991679796826789,0.6980898283493966,2.815264657203417,1.5630049818045095,2.2016451014512763,3592.2219106309676,2077.892711098087,1.097345623668049,6.432261593907748,2.323121774549769,4.566676452572013,37.22007951466741,21.863525491939058,3563.771739422927,2058.7977817153733,0.7032185938487943,1.3460948638803791,1.0258087931960578,3.282512609979646,1.020097091939939,1.6765373002546502,3562.321577294196,2059.6260832360026,0.3793051679410979,2.4339167752397506,2.3129876287533495,3.1780893658791003,1.3291028180994529,1.9487766155137847,3597.923442956406,2085.929079616092,2.2597429298545606,4.834074668475977,3.0604475964971463,6.021468437347902,32.34128359494465,19.42075721961028,3575.6954460919883,2067.702648540873,1.076717624117365,3.3571952031653236,1.4307398949902925,2.563819969040103,4.406271491528889,3.7584148005377136,3577.206512122848,2067.539128183607,1.1788468565001409,2.510919269354336,0.32738768698897985,2.487043070157524,5.1209657828557384,3.507585469794522,3587.442346555768,2074.0994486622244,1.223180769573508,3.815767881667613,1.2680295927869365,3.623826023435559,12.551862357641962,8.02108558165991,3576.522935725296,2070.8035757873313,2.227691773021745,3.8238334192855166,1.7405671413156032,5.189311565138333,23.653521913834563,14.716233172991808,3592.495257034544,2081.3037138946324,3.019699621726053,6.795930730804626,0.7013168898250711,6.877517411530832,37.61760386849331,21.02904064025458,3578.3927647607156,2068.9472403185932,1.8036290992207962,3.769555282145583,0.8030650739709411,1.7197100693401681,2.5119098817479006,2.7213916824362085,3618.2833766268604,2098.2392336932403,2.683676489992122,4.947712774932949,2.386348306015216,4.194867360066908,28.49026450072829,16.591708829652337,3586.4012211254017,2080.236179200983,1.6187746454567484,4.885144588206499,1.5605927923297542,5.375388104409942,34.782938993612746,19.500570100078747)
input_data_as_numpy_array1 = np.asarray(input_data1)
#reshape the array as we predicting for one instance
input_data_reshape1 = input_data_as_numpy_array1.reshape(1,-1)

#standardize the input data
std_data1 = sc.transform(input_data_reshape1)
print(std_data1)

prediction1 = clf2.predict(std_data1)
print(prediction1)

if (prediction1[0] == 0):
    print("The person in thinking neutral")
elif (prediction1[0] == 1):
    print("The person is thinking right movement:")
elif(prediction1[0] == 2):
    print("The person is thinking left movement:")
# Out:
#  training Accuracy due to svm 88.95%
# testing Accuracy due to svm 74.57 %
# [[ 8.57824859e-01  7.63075413e-01 -8.01118857e-01 -1.17226457e+00
#   -1.85385702e-01  6.15839466e-02  8.66498741e-01 -9.46204227e-01
#    2.67179157e+00  1.70548224e+00  1.40916470e+00  1.27627459e+00
#   -5.65590935e-01  1.15878330e+00  9.44195368e-01  2.56990378e-04
#   -4.72438353e-01 -8.07350258e-01 -1.13299321e+00 -7.51791270e-01
#   -9.13889252e-01 -1.16667791e+00 -1.08469394e-01 -1.37206046e+00
#    1.70108229e-01 -2.06411528e-01 -9.92875714e-02 -6.76681093e-01
#    7.40375402e-01  2.39590419e+00 -1.43156370e-01 -4.58243479e-01
#    4.80315245e-01  1.08576654e+00 -1.10577608e+00  8.07101593e-01
#    2.96785247e+00  1.52834457e+00  1.17691684e+00  9.20947662e-02
#   -3.35907551e-02 -3.78587310e-01 -8.91138199e-01 -8.36957380e-01
#   -7.69750728e-01 -1.06944162e+00 -1.05810718e-01 -1.26668326e+00
#    1.25024727e+00  1.71627098e+00 -4.29907597e-02  9.68788143e-01
#    3.88963717e-01 -3.98218455e-01  8.18928125e-02 -1.43610886e+00
#    1.70973777e-01 -2.41906884e-01 -4.33665546e-01 -3.80625339e-01
#   -6.21407248e-01 -5.13033364e-01 -5.30271570e-01 -7.17482455e-01
#   -7.51321867e-02 -4.93303212e-01 -8.18489771e-01 -5.72169276e-01
#   -9.05845445e-01 -9.74419280e-01 -1.49033346e-01 -1.51114047e+00
#   -1.22963856e-01 -4.82756409e-01 -6.82113561e-01 -7.34155861e-01
#   -8.10709792e-01 -8.70348121e-01 -2.00056242e-01 -1.17630116e+00
#   -4.76591669e-01 -7.19222714e-01 -7.75981218e-01 -7.38419278e-01
#   -1.21144774e+00 -1.00687054e+00  3.25494107e-02 -1.41669469e+00
#    1.04109431e-01 -7.19029233e-02  3.54421923e-01  8.46221893e-02
#   -7.12248162e-01 -9.29831104e-01 -7.94588576e-01 -1.35491677e+00
#   -1.85949259e-01 -4.60023224e-01 -7.25321937e-01 -7.73184753e-01
#   -7.69825351e-01 -1.09982758e+00 -1.55826944e-01 -1.26325020e+00
#   -5.71179769e-01 -7.94123508e-01 -1.00096597e+00 -8.71284340e-01
#   -1.00648574e+00 -1.09262933e+00 -1.08376391e-01 -1.37714032e+00]]
# [2.]
# The person is thinking left movement:

# %% [markdown]
# # k nearest neighbors

# %%
#k-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
clf3 = KNeighborsClassifier()
clf3.fit(X_train, y_train)
y_pred_knn = clf3.predict(X_test)


from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
predictions2 =classifier.predict(X_test)
print('Predicted labels: ', predictions2)
print('Actual labels:    ' ,y_test)
from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_test, predictions2)*100,'%')
# Out:
# Predicted labels:  [0. 0. 0. ... 0. 2. 1.]
# Actual labels:     [1. 0. 1. ... 0. 2. 2.]
# Accuracy: 82.29166666666666 %

# %% [markdown]
# # k  nearest neighbors predictive model

# %%
from sklearn.neighbors import KNeighborsClassifier
clf3 = KNeighborsClassifier()
clf3.fit(X_train, y_train)
X_training_knn = clf3.predict(X_train)
acc_knn = round(accuracy_score(X_training_knn, y_train) * 100, 2)
print ('training  accuracy due to k-nearest neighbors',str(acc_knn)+'%')

X_test_knn_prediction = clf3.predict(X_test)
acc_knn = round(accuracy_score(X_test_knn_prediction, y_test)*100,2)
print ('Testing accuracy due to k-nearest neighbors',str(acc_knn) + ' %')


input_data2 = (71.576698564637,2063.503373184418,0.6029205352726208,2.967502905177528,1.4389885333016486,3.295020474122926,2.052318300662066,3.1929348458678626,3563.866619628976,2060.286630465621,1.2048099804200265,2.8103413736129825,0.27225772874660253,3.2862951557027094,1.0678356137575986,1.9728319154162408,3652.2514313778815,2127.7279583112304,13.27429161159918,34.36241292717517,36.26740246352244,56.93358683986829,48.214204584167035,74.47805088211938,3567.9662227438766,2061.7293157396007,0.5639959873004751,1.8721454702989053,1.4744399511095823,3.151339493976347,1.1046383080327566,1.9720318177527565,3557.726002755468,2055.8270423349927,0.891967376033974,2.669653114283589,1.5092077923923408,3.223965144639929,1.1366182390371824,2.1194584472732623,3629.0269092328194,2112.43573527682,13.547810600175742,33.42932882710743,32.38408386460878,56.56392200821375,46.852538109751684,75.99428250396319,3572.7670294266136,2064.8107935615335,1.1138945552313306,3.087238282060807,2.594065151630992,3.6937640590190437,3.743236375279487,5.449513343688413,3624.6588025440947,2117.797875892098,17.72209210101678,44.826561263290984,45.20186494044083,70.46932926197067,52.01336589318217,78.6992320452235,3574.8087842736973,2069.4394015495755,3.9431400426464016,10.523827732442765,9.784315414140655,16.80055893338254,16.40704563679004,29.77800027885906,3599.12334525423,2092.832289859586,10.32278916169577,31.94580621129784,27.862453555402396,51.41803859432595,42.988782306876445,69.05913364184316,3644.8426227370746,2124.2769771486005,13.791168423040311,35.1227944717199,35.803994796177,52.92858607598883,47.091113299675946,75.77059064746959,3574.582758813449,2065.692541804272,0.9280601508137211,2.6745293039707225,1.7775098800923772,3.4632397601696416,3.531847362428501,4.635422446750105,3612.975093711585,2106.3912922348186,10.486696520513933,34.594568511354616,31.14109960070707,57.91657781776544,46.74556734516573,76.699566475851,3687.0169057606745,2147.3154736112638,11.454735106178045,34.232922759264135,35.43148877248333,58.78652499474915,48.76385063044414,77.23551806293348)
input_data_as_numpy_array2 = np.asarray(input_data2)
#reshape the array as we predicting for one instance
input_data_reshape2 = input_data_as_numpy_array2.reshape(1,-1)

#standardize the input data
std_data2 = sc.transform(input_data_reshape2)
print(std_data2)

prediction2 = clf3.predict(std_data2)
print(prediction2)

if (prediction2[0] == 0):
    print("The person in thinking neutral")
elif (prediction2[0] == 1):
    print("The person is thinking right movement:")
elif(prediction2[0] == 2):
    print("The person is thinking left movement:")
# Out:
# training  accuracy due to k-nearest neighbors 91.78%
# Testing accuracy due to k-nearest neighbors 82.29 %
# [[ 3.02806474e+09 -1.11827989e+00 -8.89381855e-01  5.11254228e-01
#    1.10903535e+00  1.28052911e+00 -3.02492963e-01 -2.89322960e-01
#   -1.67079215e+00 -1.03004037e+00  6.93977141e-01  9.84525495e-01
#   -1.64801909e+00  1.98946887e+00 -6.41765574e-01 -8.55775636e-01
#    1.13580969e+00  5.25301069e-01  1.09687654e+00  9.47428585e-01
#    4.59333780e+00  2.75383548e+00  6.12570261e-01  2.27780412e+00
#    1.97342138e+00  1.58067303e+00 -4.75208033e-01  1.62018709e-01
#    1.93732365e+00  2.18455364e+00  9.60090707e-02  1.76923946e-01
#   -1.45947560e+00 -1.44339341e+00  2.45714544e-01  1.19495794e+00
#    1.24373269e+00  1.59674975e+00  4.82562013e-01  5.09007281e-01
#    9.47857497e-01  4.78385779e-01  1.59159239e+00  1.28420775e+00
#    4.84388622e+00  3.48561708e+00  8.74541645e-01  2.95630976e+00
#   -1.71717405e-01 -5.48504526e-01  3.28216802e-02  6.09153057e-01
#    2.54534404e+00  9.30465295e-01 -5.91222336e-01  3.44293641e-02
#    1.62422199e+00  9.98669422e-01  1.97324277e+00  1.52249983e+00
#    6.58788830e+00  3.79265772e+00  1.43950026e+00  2.98474624e+00
#   -1.74793095e+00 -1.33727041e+00  1.41741514e+00  1.55322107e+00
#    4.35627877e+00  3.01542108e+00  8.05979642e-01  3.20583883e+00
#    5.56485748e-01  2.61533298e-01  1.52305296e+00  1.70230055e+00
#    5.36698776e+00  4.19939230e+00  1.41143296e+00  3.67743746e+00
#    9.93526751e-01  4.89918167e-01  1.33461336e+00  1.14807820e+00
#    4.96706326e+00  2.76679430e+00  6.90522757e-01  2.71325994e+00
#   -4.37177787e-02 -2.31194710e-01 -5.53219604e-01 -3.25406374e-01
#    6.98698843e-01  1.96954246e-01 -5.23077047e-02 -1.68355105e-01
#   -3.45824046e-01 -1.89292103e-01  1.09847956e+00  1.55821028e+00
#    5.03749636e+00  3.98156329e+00  1.15144798e+00  3.36665561e+00
#    2.13215909e+00  1.19205627e+00  9.66936239e-01  1.22384417e+00
#    4.84214631e+00  3.33951153e+00  7.98540648e-01  2.69171681e+00]]
# [0.]
# The person in thinking neutral

# %%
# !pip install --upgrade tabulate
# Out:
# Requirement already satisfied: tabulate in c:\users\user\anaconda3\lib\site-packages (0.8.10)

# %%
# !pip install --upgrade simple_colors
# Out:
# Requirement already satisfied: simple_colors in c:\users\user\anaconda3\lib\site-packages (0.1.5)

# %%
# import module
from tabulate import tabulate
from simple_colors import *
# assign data
mydata = [
[black('K NEAREST NEIGHBORS','bold'),black(accuracy_score(y_test, predictions2)*100,'bold')],
[black('SUPPORT VECTOR MACHINES','bold'),black(accuracy_score(y_test, predictions1)*100,'bold')],
[black('LOGISTIC REGRESSION','bold'),black(accuracy_score(y_test, predictions0)*100,'bold')]
]

# create header

head = [(red('Classifier','bold')),(red('Accuracy(%)','bold')),'\033[1m']
'Accuracy(%)'
# display table
print(tabulate(mydata, headers=head, tablefmt="grid"))
# Out:
# +-------------------------+---------------+
# | Classifier              |   Accuracy(%) |
# +=========================+===============+
# | K NEAREST NEIGHBORS     |       82.2917 |
# +-------------------------+---------------+
# | SUPPORT VECTOR MACHINES |       59.6354 |
# +-------------------------+---------------+
# | LOGISTIC REGRESSION     |       59.2014 |
# +-------------------------+---------------+
