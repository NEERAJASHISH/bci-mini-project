# %%
plt.scatter(ESR['AF3 delta std'],ESR['AF3 delta m'])
#Scatter plots are used to observe relationship between variables and uses dots to represent the relationship between them. The scatter() method in the matplotlib library is used to draw a scatter plot.

# %%
plt.scatter(ESR['AF3 theta std'],ESR['AF3 theta m'])

# %%
plt.scatter(ESR['AF3 alpha std'],ESR['AF3 alpha m'])

# %%
plt.scatter(ESR['AF3 beta std'],ESR['AF3 beta m'])

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.4,random_state=0)

# %%
#StandardScaler performs the task of Standardization. Usually a dataset contains variables that are different in scale. For e.g. an Employee dataset will contain AGE column with values on scale 20-70 and SALARY column with values on scale 10000-80000.
#As these two columns are different in scale, they are Standardized to have common scale while building machine learning model

# %% [markdown]
# fit_transform() is used on the training data so that we can scale the training data and also learn the scaling parameters of that data. Here, the model built by us will learn the mean and variance of the features of the training set. These learned parameters are then used to scale our test data.
#
# So what actually is happening here! 🤔
#
# The fit method is calculating the mean and variance of each of the features present in our data. The transform method is transforming all the features using the respective mean and variance.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-26c922498595> in <module>
#       1 from sklearn import tree
#       2 clf = tree.DecisionTreeClassifier()
# ----> 3 clf = clf.fit(X_train,)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
from sklearn.linear_model import LogisticRegression
clf1 = LogisticRegression()


clf1.fit(X_train, y_train) #train a model
y_pred_log_reg = clf1.predict(X_test)
print(y_pred_log_reg)
acc_log_reg = round(clf1.score(X_test, y_test) * 100, 2) # compares and gives accuracy
print(acc_log_reg)
print (str(acc_log_reg) + ' %')

# Set regularization rate What is Regularization? Regularization is one of the most important concepts of machine learning. It is a technique to prevent the model from overfitting by adding extra information to it. Sometimes the machine learning model performs well with the training data but does not perform well with the test data.
reg = 1
# train a logistic regression model on the training set
model0 = LogisticRegression(C=0.1/reg, solver="liblinear").fit(X_train, y_train)
#LIBLINEAR is a linear classifier for data with millions of instances and features. It supports. L2-regularized classifiers. L2-loss linear SVM, L1-loss linear SVM, and logistic regression (LR) L1-regularized classifiers (after version 1.4)
print (model0)

predictions0 = model0.predict(X_test)
print('Predicted labels: ', predictions0)
print('Actual labels:    ' ,y_test)


from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_test, predictions0)*100,'%')


print(y_test)
# Out:
# c:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [0. 0. 0. ... 0. 2. 2.]
# 60.76
# 60.76 %
# LogisticRegression(C=0.1, solver='liblinear')
# Predicted labels:  [0. 0. 0. ... 0. 2. 2.]
# Actual labels:     [1. 0. 1. ... 0. 2. 2.]
# Accuracy: 59.201388888888886 %
# [1. 0. 1. ... 0. 2. 2.]

# %%
from sklearn.linear_model import LogisticRegression
clf1 = LogisticRegression()

from sklearn.metrics import accuracy_score
clf1.fit(X_train, y_train) #train a model
y_pred_log_reg = clf1.predict(X_train)
print(y_pred_log_reg)
trainig_data_accutracy = accuracy_score(y_pred_log_reg,y_train)
print(trainig_data_accutracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c10ce8ab784b> in <module>
#       3
#       4 from sklearn.metrics import accuracy_score
# ----> 5 clf1.fit(X_train, y_train) #train a model
#       6 y_pred_log_reg = clf1.predict(X_train)
#       7 print(y_pred_log_reg)
#
# NameError: name 'X_train' is not defined
